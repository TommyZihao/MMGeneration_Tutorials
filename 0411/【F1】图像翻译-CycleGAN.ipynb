# %% [markdown]
# # 图像翻译（Image Translation） 之 CycleGAN

# %% [markdown]
# 在 MMGeneration中调用 Image Translation 预训练模型
#
# > 作者：[同济子豪兄](https://space.bilibili.com/1900783)、杨逸飞 2022-4-10

# %% [markdown]
# ## 进入MMGeneration主目录

# %%
import os
os.chdir('mmgeneration')
os.listdir()
# Out:
# ['.git',
#  '.dev_scripts',
#  '.github',
#  '.gitignore',
#  '.pre-commit-config.yaml',
#  '.pylintrc',
#  '.readthedocs.yml',
#  'CITATION.cff',
#  'LICENSE',
#  'LICENSES.md',
#  'MANIFEST.in',
#  'README.md',
#  'README_zh-CN.md',
#  'apps',
#  'configs',
#  'demo',
#  'docker',
#  'docs',
#  'mmgen',
#  'model-index.yml',
#  'requirements.txt',
#  'requirements',
#  'setup.cfg',
#  'setup.py',
#  'tests',
#  'tools',
#  'mmgen.egg-info',
#  'outputs',
#  'data',
#  'checkpoints',
#  'work_dirs']

# %% [markdown]
# ## MMGeneration 支持的 CycleGAN 模型
#
# https://github.com/open-mmlab/mmgeneration/blob/master/configs/cyclegan/README.md
#
# CycleGAN 数据集来源：https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/

# %% [markdown]
# ## 命令行方式调用

# %%
# !python demo/translation_demo.py -h
# Out:
# usage: translation_demo.py [-h] [--target-domain TARGET_DOMAIN]
#                            [--save-path SAVE_PATH] [--device DEVICE]
#                            [--sample-cfg SAMPLE_CFG [SAMPLE_CFG ...]]
#                            config checkpoint image_path
#
# Translation demo
#
# positional arguments:
#   config                test config file path
#   checkpoint            checkpoint file
#   image_path            Image file path
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --target-domain TARGET_DOMAIN
#                         Desired image domain
#   --save-path SAVE_PATH
#                         path to save translation sample
#   --device DEVICE       CUDA device id
#   --sample-cfg SAMPLE_CFG [SAMPLE_CFG ...]
#                         Other customized kwargs for sampling function

# %% [markdown]
# 命令行基本语法：

# %% [markdown]
# ### CycleGAN 夏天转冬天

# %%
# !python demo/translation_demo.py \
        configs/cyclegan/cyclegan_lsgan_resnet_in_summer2winter_b1x1_250k.py \
        https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth \
        --target-domain winter \
        data/memory1.jpg \
        --save-path outputs/E2_summer2winter_1.jpg \
        --device cuda:0
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth

# %%
# !python demo/translation_demo.py \
        configs/cyclegan/cyclegan_lsgan_resnet_in_summer2winter_b1x1_250k.py \
        https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth \
        --target-domain winter \
        data/summer1.jpg \
        --save-path outputs/E2_summer2winter_2.jpg \
        --device cuda:0
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth

# %% [markdown]
# ### CycleGAN 冬天转夏天

# %%
# !python demo/translation_demo.py \
        configs/cyclegan/cyclegan_lsgan_id0_resnet_in_summer2winter_b1x1_250k.py \
        https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_id0_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165640-8b825581.pth \
        --target-domain summer \
        data/winter3.jpg \
        --save-path outputs/E2_winter2summer_3.jpg \
        --device cuda:0
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_id0_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165640-8b825581.pth

# %% [markdown]
# ### CycleGAN 野马变斑马

# %%
# !python demo/translation_demo.py \
        configs/cyclegan/cyclegan_lsgan_resnet_in_horse2zebra_b1x1_270k.py \
        https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_266800_horse2zebra_convert-bgr_20210902_170004-a32c733a.pth \
        --target-domain zebra \
        data/horse1.jpg \
        --save-path outputs/E2_horse2zebra_1.jpg \
        --device cuda:0
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_266800_horse2zebra_convert-bgr_20210902_170004-a32c733a.pth

# %% [markdown]
# ### CycleGAN 斑马变野马

# %%
# !python demo/translation_demo.py \
        configs/cyclegan/cyclegan_lsgan_resnet_in_horse2zebra_b1x1_270k.py \
        https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_266800_horse2zebra_convert-bgr_20210902_170004-a32c733a.pth \
        --target-domain horse \
        data/zebra1.jpg \
        --save-path outputs/E2_zebra2horse_1.jpg \
        --device cuda:0
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_266800_horse2zebra_convert-bgr_20210902_170004-a32c733a.pth

# %% [markdown]
# ### CycleGAN 涂鸦转建筑立面图

# %%
import cv2
img = cv2.imread('tests/data/paired/test/3.jpg')

# %%
img.shape
# Out:
# (256, 512, 3)

# %%
img1 = img[:,0:256,:]
img2 = img[:,256:,:]

# %%
img1.shape
# Out:
# (256, 256, 3)

# %%
img2.shape
# Out:
# (256, 256, 3)

# %%
cv2.imwrite('data/facades1.jpg', img1)
cv2.imwrite('data/facades2.jpg', img2)
# Out:
# True

# %%
# !python demo/translation_demo.py \
        configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k.py \
        https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_80k_facades_20210902_165905-5e2c0876.pth \
        --target-domain photo \
        data/facades2.jpg \
        --save-path outputs/E2_facades_mask2photo.jpg \
        --device cuda:0
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_80k_facades_20210902_165905-5e2c0876.pth

# %% [markdown]
# ### CycleGAN 建筑立面图转涂鸦

# %%
# !python demo/translation_demo.py \
        configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k.py \
        https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_80k_facades_20210902_165905-5e2c0876.pth \
        --target-domain mask \
        data/facades1.jpg \
        --save-path outputs/E2_facades_photo2mask.jpg \
        --device cuda:0
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_80k_facades_20210902_165905-5e2c0876.pth

# %% [markdown]
# ## Python API 方式调用

# %% [markdown]
# ### 导入工具包

# %%
# 导入mmcv和mmgeneration
import mmcv
from mmgen.apis import init_model, sample_img2img_model

# 导入 opencv
import cv2

# 导入numpy和matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 定义可视化图像函数，输入图像 array，可视化图像
def show_img_from_path(img_path):
    '''输入 array，matplotlib 可视化格式为 RGB，因此需将 BGR 转 RGB，最后可视化出来'''
    img_BGR = cv2.imread(img_path)
    img_RGB = cv2.cvtColor(img_BGR, cv2.COLOR_BGR2RGB)
    plt.imshow(img_RGB)
    plt.show()

# %% [markdown]
# ### 载入预训练 CycleGAN 模型
#
# 注意，`config_file`和`checkpoint_file`需要对应。

# %%
# 夏天转冬天

# 指定config文件路径
config_file = 'configs/cyclegan/cyclegan_lsgan_resnet_in_summer2winter_b1x1_250k.py'

# 指定预训练模型权重文件路径
checkpoint_file = 'https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth'

# 输出图像宽高像素尺寸
img_size = 256

# %%
# # 野马转斑马

# # 指定config文件路径
# config_file = 'configs/cyclegan/cyclegan_lsgan_resnet_in_horse2zebra_b1x1_270k.py'

# # 指定预训练模型权重文件路径
# checkpoint_file = 'https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_266800_horse2zebra_convert-bgr_20210902_170004-a32c733a.pth'

# %% [markdown]
# ### 初始化模型

# %%
model = init_model(config_file, checkpoint_file, device='cuda:0')
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# load checkpoint from http path: https://download.openmmlab.com/mmgen/cyclegan/refactor/cyclegan_lsgan_resnet_in_1x1_246200_summer2winter_convert-bgr_20210902_165932-fcf08dc1.pth

# %% [markdown]
# ### 生成图像

# %% [markdown]
# 调用`sample_img2img_model`函数，指定模型和输入图像

# %%
# 指定输入图像
image_path = 'data/summer1.jpg'

# %%
fake_imgs = sample_img2img_model(model, image_path, target_domain='winter')

# %%
fake_imgs.shape
# Out:
# torch.Size([1, 3, 256, 256])

# %% [markdown]
# ### 展示单张生成的图像

# %%
# 将torch张量转为numpy的array
fake_imgs = fake_imgs.numpy()

# %%
fake_imgs.shape
# Out:
# (1, 3, 256, 256)

# %%
# 选择要展示的图片索引号
index = 0

# 分别抽取RGB三通道图像，归一化为0-255的uint8自然图像
RGB = np.zeros((img_size,img_size,3))
RGB[:,:,0] = fake_imgs[index][2]
RGB[:,:,1] = fake_imgs[index][1]
RGB[:,:,2] = fake_imgs[index][0]

RGB = 255 * (RGB - RGB.min()) / (RGB.max()-RGB.min())
RGB = RGB.astype('uint8')
plt.imshow(RGB)
plt.show()

# %%
# 展示原始输入图像
show_img_from_path(image_path)
