# %% [markdown]
# # 训练 CycleGAN 实现照片转莫奈印象派画风

# %% [markdown]
# > 作者：[同济子豪兄](https://space.bilibili.com/1900783)、杨逸飞 2022-4-10

# %% [markdown]
# ## 进入MMGeneration主目录

# %%
import os
os.chdir('mmgeneration')
os.listdir()
# Out:
# ['.git',
#  '.dev_scripts',
#  '.github',
#  '.gitignore',
#  '.pre-commit-config.yaml',
#  '.pylintrc',
#  '.readthedocs.yml',
#  'CITATION.cff',
#  'LICENSE',
#  'LICENSES.md',
#  'MANIFEST.in',
#  'README.md',
#  'README_zh-CN.md',
#  'apps',
#  'configs',
#  'demo',
#  'docker',
#  'docs',
#  'mmgen',
#  'model-index.yml',
#  'requirements.txt',
#  'requirements',
#  'setup.cfg',
#  'setup.py',
#  'tests',
#  'tools',
#  'mmgen.egg-info',
#  'outputs',
#  'data',
#  'checkpoints',
#  'work_dirs']

# %% [markdown]
# ## 下载 monet2photo 数据集
#
# 下载地址：https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/

# %%
# 下载 monet2photo 图像数据集压缩包
# !wget https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/monet2photo.zip -O data/monet2photo.zip

# %%
# 解压至 data/monet2photo 目录
# !unzip -o data/monet2photo.zip -d data/monet2photo/
# Out:
# Archive:  data/monet2photo.zip
#    creating: data/monet2photo/monet2photo/
#    creating: data/monet2photo/monet2photo/trainA/
#   inflating: data/monet2photo/monet2photo/trainA/01159.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01048.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01144.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00799.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00897.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00998.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00883.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00985.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00311.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01243.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01259.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00454.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00461.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01283.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00901.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00502.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00176.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01157.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00935.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00929.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00837.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00444.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00808.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01009.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01324.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01278.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01229.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00625.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00652.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00056.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00899.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01115.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00725.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00063.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01153.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00731.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00537.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01183.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00358.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00486.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00982.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00019.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00139.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00873.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00741.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00034.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00651.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00169.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01281.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00178.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00742.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00923.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00592.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01152.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00996.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00534.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00157.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00977.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00807.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00971.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00484.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00015.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00345.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00524.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01028.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00294.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01077.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01241.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01292.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00634.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00518.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00536.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00242.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00307.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00147.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01141.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00631.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01191.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00809.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00966.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01235.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00644.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01321.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00078.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01105.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00805.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00446.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01227.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00459.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01177.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00207.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00871.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00158.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00609.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00841.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00125.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00349.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00027.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00962.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00382.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00969.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00109.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00164.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00767.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00726.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01275.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00219.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00972.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01081.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00997.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00389.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01188.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01204.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00012.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01247.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00548.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00687.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00539.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01044.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00193.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00291.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00388.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01131.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00432.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00452.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00275.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00199.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00329.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01322.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01175.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00121.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01337.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00928.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00712.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00343.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01239.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00491.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01006.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01244.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01092.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00608.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00148.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01016.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00978.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00045.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00117.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00943.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00677.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01181.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00161.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00816.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01198.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00865.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01148.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00864.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01303.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01031.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00597.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01121.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00404.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00523.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00594.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01051.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00469.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00638.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00813.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00451.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01145.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00471.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00033.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01059.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01282.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01066.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00204.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00633.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00845.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00613.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01067.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00191.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00185.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01062.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00611.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00328.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01072.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00122.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01209.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01248.jpg
#   inflating: data/monet2photo/monet2photo/trainA/00083.jpg
#   inflating: data/monet2photo/monet2photo/trainA/01257.jpg
#   inflating: data/monet2photo/monet2photo/trainA/
#   inflating: data/monet2photo/monet2photo/testA/00060.jpg
#   inflating: data/monet2photo/monet2photo/testA/00210.jpg
#   inflating: data/monet2photo/monet2photo/testA/00190.jpg
#   inflating: data/monet2photo/monet2photo/testA/00200.jpg
#   inflating: data/monet2photo/monet2photo/testA/00460.jpg

# %% [markdown]
# ### 配置 config 文件

# %%
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/cyclegan_lsgan_resnet_in_facades_b1x1_80k_monet2photo.py -O configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_monet2photo.py

# %% [markdown]
# ## 在自己的数据集上训练模型(运行半小时左右)
#
# 训练过程中，在 work_dirs/experiments/experiments_name目录下
#
# training_samples保存了训练过程中达到不同迭代次数时的训练效果
#
# ckpt/experiments_name保存了训练过程中达到不同迭代次数时的模型权重文件

# %%
# !bash tools/dist_train.sh configs/cyclegan/cyclegan_lsgan_resnet_in_facades_b1x1_80k_monet2photo.py 1 --work-dir work_dirs/experiments/cyclegan_monet2photo
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# tools/train.py:98: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   f'Setting OMP_NUM_THREADS environment variable for each process '
# tools/train.py:108: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   f'Setting MKL_NUM_THREADS environment variable for each process '
# 2022-04-11 11:59:51,089 - mmgen - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.2.r11.2/compiler.29618528_0
# GPU 0: NVIDIA GeForce RTX 3060
# GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
# PyTorch: 1.10.1+cu113
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
# TorchVision: 0.11.2+cu113
# OpenCV: 4.5.4
# MMCV: 1.4.8
# MMGen: 0.7.0+5457cd5
# MMCV Compiler: GCC 7.3
# MMCV CUDA Compiler: 11.3
# ------------------------------------------------------------
#
# 2022-04-11 11:59:51,589 - mmgen - INFO - Distributed training: True
# 2022-04-11 11:59:51,909 - mmgen - INFO - Config:
# _domain_a = None
# _domain_b = None
# model = dict(
#     type='CycleGAN',
#     generator=dict(
#         type='ResnetGenerator',
#         in_channels=3,
#         out_channels=3,
#         base_channels=64,
#         norm_cfg=dict(type='IN'),
#         use_dropout=False,
#         num_blocks=9,
#         padding_mode='reflect',
#         init_cfg=dict(type='normal', gain=0.02)),
#     discriminator=dict(
#         type='PatchDiscriminator',
#         in_channels=3,
#         base_channels=64,
#         num_conv=3,
#         norm_cfg=dict(type='IN'),
#         init_cfg=dict(type='normal', gain=0.02)),
#     gan_loss=dict(
#         type='GANLoss',
#         gan_type='lsgan',
#         real_label_val=1.0,
#         fake_label_val=0.0,
#         loss_weight=1.0),
#     default_domain='photo',
#     reachable_domains=['monet', 'photo'],
#     related_domains=['monet', 'photo'],
#     gen_auxiliary_loss=[
#         dict(
#             type='L1Loss',
#             loss_weight=10.0,
#             loss_name='cycle_loss',
#             data_info=dict(pred='cycle_monet', target='real_monet'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=10.0,
#             loss_name='cycle_loss',
#             data_info=dict(pred='cycle_photo', target='real_photo'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=0.5,
#             loss_name='id_loss',
#             data_info=dict(pred='identity_monet', target='real_monet'),
#             reduction='mean'),
#         dict(
#             type='L1Loss',
#             loss_weight=0.5,
#             loss_name='id_loss',
#             data_info=dict(pred='identity_photo', target='real_photo'),
#             reduction='mean')
#     ])
# train_cfg = dict(buffer_size=50)
# test_cfg = None
# train_dataset_type = 'UnpairedImageDataset'
# val_dataset_type = 'UnpairedImageDataset'
# img_norm_cfg = dict(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
# domain_a = 'monet'
# domain_b = 'photo'
# train_pipeline = [
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_monet',
#         flag='color'),
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_photo',
#         flag='color'),
#     dict(
#         type='Resize',
#         keys=['img_monet', 'img_photo'],
#         scale=(286, 286),
#         interpolation='bicubic'),
#     dict(
#         type='Crop',
#         keys=['img_monet', 'img_photo'],
#         crop_size=(256, 256),
#         random_crop=True),
#     dict(type='Flip', keys=['img_monet'], direction='horizontal'),
#     dict(type='Flip', keys=['img_photo'], direction='horizontal'),
#     dict(type='RescaleToZeroOne', keys=['img_monet', 'img_photo']),
#     dict(
#         type='Normalize',
#         keys=['img_monet', 'img_photo'],
#         to_rgb=False,
#         mean=[0.5, 0.5, 0.5],
#         std=[0.5, 0.5, 0.5]),
#     dict(type='ImageToTensor', keys=['img_monet', 'img_photo']),
#     dict(
#         type='Collect',
#         keys=['img_monet', 'img_photo'],
#         meta_keys=['img_monet_path', 'img_photo_path'])
# ]
# test_pipeline = [
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_monet',
#         flag='color'),
#     dict(
#         type='LoadImageFromFile',
#         io_backend='disk',
#         key='img_photo',
#         flag='color'),
#     dict(
#         type='Resize',
#         keys=['img_monet', 'img_photo'],
#         scale=(256, 256),
#         interpolation='bicubic'),
#     dict(type='RescaleToZeroOne', keys=['img_monet', 'img_photo']),
#     dict(
#         type='Normalize',
#         keys=['img_monet', 'img_photo'],
#         to_rgb=False,
#         mean=[0.5, 0.5, 0.5],
#         std=[0.5, 0.5, 0.5]),
#     dict(type='ImageToTensor', keys=['img_monet', 'img_photo']),
#     dict(
#         type='Collect',
#         keys=['img_monet', 'img_photo'],
#         meta_keys=['img_monet_path', 'img_photo_path'])
# ]
# data_root = None
# data = dict(
#     samples_per_gpu=1,
#     workers_per_gpu=4,
#     drop_last=True,
#     val_samples_per_gpu=1,
#     val_workers_per_gpu=0,
#     train=dict(
#         type='UnpairedImageDataset',
#         dataroot='./data/monet2photo/monet2photo/',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_monet',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_photo',
#                 flag='color'),
#             dict(
#                 type='Resize',
#                 keys=['img_monet', 'img_photo'],
#                 scale=(286, 286),
#                 interpolation='bicubic'),
#             dict(
#                 type='Crop',
#                 keys=['img_monet', 'img_photo'],
#                 crop_size=(256, 256),
#                 random_crop=True),
#             dict(type='Flip', keys=['img_monet'], direction='horizontal'),
#             dict(type='Flip', keys=['img_photo'], direction='horizontal'),
#             dict(type='RescaleToZeroOne', keys=['img_monet', 'img_photo']),
#             dict(
#                 type='Normalize',
#                 keys=['img_monet', 'img_photo'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_monet', 'img_photo']),
#             dict(
#                 type='Collect',
#                 keys=['img_monet', 'img_photo'],
#                 meta_keys=['img_monet_path', 'img_photo_path'])
#         ],
#         test_mode=False,
#         domain_a='monet',
#         domain_b='photo'),
#     val=dict(
#         type='UnpairedImageDataset',
#         dataroot='./data/monet2photo/monet2photo/',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_monet',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_photo',
#                 flag='color'),
#             dict(
#                 type='Resize',
#                 keys=['img_monet', 'img_photo'],
#                 scale=(256, 256),
#                 interpolation='bicubic'),
#             dict(type='RescaleToZeroOne', keys=['img_monet', 'img_photo']),
#             dict(
#                 type='Normalize',
#                 keys=['img_monet', 'img_photo'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_monet', 'img_photo']),
#             dict(
#                 type='Collect',
#                 keys=['img_monet', 'img_photo'],
#                 meta_keys=['img_monet_path', 'img_photo_path'])
#         ],
#         test_mode=True,
#         domain_a='monet',
#         domain_b='photo'),
#     test=dict(
#         type='UnpairedImageDataset',
#         dataroot='./data/monet2photo/monet2photo/',
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_monet',
#                 flag='color'),
#             dict(
#                 type='LoadImageFromFile',
#                 io_backend='disk',
#                 key='img_photo',
#                 flag='color'),
#             dict(
#                 type='Resize',
#                 keys=['img_monet', 'img_photo'],
#                 scale=(256, 256),
#                 interpolation='bicubic'),
#             dict(type='RescaleToZeroOne', keys=['img_monet', 'img_photo']),
#             dict(
#                 type='Normalize',
#                 keys=['img_monet', 'img_photo'],
#                 to_rgb=False,
#                 mean=[0.5, 0.5, 0.5],
#                 std=[0.5, 0.5, 0.5]),
#             dict(type='ImageToTensor', keys=['img_monet', 'img_photo']),
#             dict(
#                 type='Collect',
#                 keys=['img_monet', 'img_photo'],
#                 meta_keys=['img_monet_path', 'img_photo_path'])
#         ],
#         test_mode=True,
#         domain_a='monet',
#         domain_b='photo'))
# checkpoint_config = dict(interval=10000, by_epoch=False, save_optimizer=True)
# log_config = dict(interval=100, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [
#     dict(
#         type='MMGenVisualizationHook',
#         output_dir='training_samples',
#         res_name_list=['fake_monet', 'fake_photo'],
#         interval=5000)
# ]
# runner = None
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# find_unused_parameters = True
# cudnn_benchmark = True
# opencv_num_threads = 0
# mp_start_method = 'fork'
# dataroot = './data/monet2photo/monet2photo/'
# optimizer = dict(
#     generators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)),
#     discriminators=dict(type='Adam', lr=0.0002, betas=(0.5, 0.999)))
# lr_config = dict(
#     policy='Linear', by_epoch=False, target_lr=0, start=40000, interval=400)
# use_ddp_wrapper = True
# total_iters = 1000
# exp_name = 'cyclegan_monet2photo'
# work_dir = 'work_dirs/experiments/cyclegan_monet2photo'
# num_images = 106
# metrics = dict(
#     FID=dict(type='FID', num_images=106, image_shape=(3, 256, 256)),
#     IS=dict(
#         type='IS',
#         num_images=106,
#         image_shape=(3, 256, 256),
#         inception_args=dict(type='pytorch')))
# evaluation = dict(
#     type='TranslationEvalHook',
#     target_domain='photo',
#     interval=10000,
#     metrics=[
#         dict(type='FID', num_images=106, bgr2rgb=True),
#         dict(type='IS', num_images=106, inception_args=dict(type='pytorch'))
#     ],
#     best_metric=['fid', 'is'])
# gpu_ids = range(0, 1)
#
# 2022-04-11 11:59:51,910 - mmgen - INFO - Set random seed to 0, deterministic: False, use_rank_shift: False
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/cnn/bricks/conv_module.py:151: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# 2022-04-11 11:59:52,734 - mmgen - INFO - Use DDP Wrapper.
# /environment/miniconda3/lib/python3.7/site-packages/torchvision/models/inception.py:83: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   ' due to scipy/scipy#11299), please set init_weights=True.', FutureWarning)
# 2022-04-11 12:00:00,268 - mmgen - INFO - FID: Adopt Inception in pytorch style
# 2022-04-11 12:00:00,268 - mmgen - INFO - Loading Inception V3 for IS...
# 2022-04-11 12:00:00,606 - mmgen - INFO - Load Inception V3 Network from Pytorch Model Zoo for IS calculation. The results can only used for monitoring purposes. To get more accuracy IS, please use Tero's Inception V3 checkpoints and use Bicubic Interpolation with Pillow backend for image resizing. More details may refer to https://github.com/open-mmlab/mmgeneration/blob/master/docs/en/quick_run.md#is.
# /environment/miniconda3/lib/python3.7/site-packages/mmcv/runner/iter_based_runner.py:104: DeprecationWarning: setting max_iters in run is deprecated, please set max_iters in runner_config
#   'please set max_iters in runner_config', DeprecationWarning)
# 2022-04-11 12:00:00,653 - mmgen - INFO - Start running, host: featurize@featurize, work_dir: /home/featurize/work/MMGeneration教程/0409/mmgeneration/work_dirs/experiments/cyclegan_monet2photo
# 2022-04-11 12:00:00,653 - mmgen - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) TranslationEvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) VisualizationHook
# (LOW         ) IterTimerHook
# (LOW         ) TranslationEvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-04-11 12:00:00,654 - mmgen - INFO - workflow: [('train', 1)], max: 1000 iters
# 2022-04-11 12:00:00,654 - mmgen - INFO - Checkpoints will be saved to work_dirs/experiments/cyclegan_monet2photo/ckpt/cyclegan_monet2photo by HardDiskBackend.
# Traceback (most recent call last):
#   File "tools/train.py", line 228, in <module>
#     main()
#   File "tools/train.py", line 224, in main
#     meta=meta)
#   File "/home/featurize/work/MMGeneration教程/0409/mmgeneration/mmgen/apis/train.py", line 199, in train_model
#     runner.run(data_loaders, cfg.workflow, cfg.total_iters)
#   File "/environment/miniconda3/lib/python3.7/site-packages/mmcv/runner/iter_based_runner.py", line 134, in run
#     iter_runner(iter_loaders[i], **kwargs)
#   File "/environment/miniconda3/lib/python3.7/site-packages/mmcv/runner/iter_based_runner.py", line 60, in train
#     self.call_hook('before_train_iter')
#   File "/environment/miniconda3/lib/python3.7/site-packages/mmcv/runner/base_runner.py", line 309, in call_hook
#     getattr(hook, fn_name)(self)
#   File "/environment/miniconda3/lib/python3.7/site-packages/mmcv/runner/hooks/lr_updater.py", line 140, in before_train_iter
#     self.regular_lr = self.get_regular_lr(runner)
#   File "/environment/miniconda3/lib/python3.7/site-packages/mmcv/runner/hooks/lr_updater.py", line 77, in get_regular_lr
#     for _base_lr in self.base_lr[k]
#   File "/environment/miniconda3/lib/python3.7/site-packages/mmcv/runner/hooks/lr_updater.py", line 77, in <listcomp>
#     for _base_lr in self.base_lr[k]
#   File "/home/featurize/work/MMGeneration教程/0409/mmgeneration/mmgen/core/scheduler/lr_updater.py", line 44, in get_lr
#     assert max_progress >= self.start
# AssertionError
# ERROR:torch.distributed.elastic.multiprocessing.api:failed (exitcode: 1) local_rank: 0 (pid: 19928) of binary: /environment/miniconda3/bin/python
# Traceback (most recent call last):
#   File "/environment/miniconda3/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/environment/miniconda3/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/environment/miniconda3/lib/python3.7/site-packages/torch/distributed/launch.py", line 193, in <module>
#     main()
#   File "/environment/miniconda3/lib/python3.7/site-packages/torch/distributed/launch.py", line 189, in main
#     launch(args)
#   File "/environment/miniconda3/lib/python3.7/site-packages/torch/distributed/launch.py", line 174, in launch
#     run(args)
#   File "/environment/miniconda3/lib/python3.7/site-packages/torch/distributed/run.py", line 713, in run
#     )(*cmd_args)
#   File "/environment/miniconda3/lib/python3.7/site-packages/torch/distributed/launcher/api.py", line 131, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "/environment/miniconda3/lib/python3.7/site-packages/torch/distributed/launcher/api.py", line 261, in launch_agent
#     failures=result.failures,
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# tools/train.py FAILED
# ------------------------------------------------------------
# Failures:
#   <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2022-04-11_12:00:05
#   host      : featurize
#   rank      : 0 (local_rank: 0)
#   exitcode  : 1 (pid: 19928)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================
